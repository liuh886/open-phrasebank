# %% [markdown]
# # Phrasebank from PDF
#
# This notebook has the purpose of extracting the most common phrases from the training data.
#
# E.g. a academic phrasebank from a poupular [scientific writing guidebooks](http://www.phrasebank.manchester.ac.uk/), or a high level scientific journal.

# %% [markdown]
# ## Workflows

# %%
### Step 1: Load the data
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path, skip_first=1, skip_last=2):
    doc = fitz.open(pdf_path)
    text = ""
    # Determine the range of pages to include
    start_page = skip_first if skip_first else 0
    end_page = len(doc) - skip_last

    for page_number in range(start_page, end_page):
        page = doc.load_page(page_number)
        text += page.get_text("text")

    doc.close()
    return text

pdf_path = r"../data/Academic_Phrasebank.pdf"

# skip the cover and the last two page
text = extract_text_from_pdf(pdf_path, skip_first=6, skip_last=2)

# %%
text
# Out:
# "6 | P a g e  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nMajor sections \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n7 | P a g e  \n \nWriting Introductions \n \n There are many ways to introduce an academic essay or short paper. Most academic writers, \nhowever, appear to do one or more of the following in their introductions: \n \n• \nestablish the context, background and/or importance of the topic \n• \nindicate an issue, problem, or controversy in the field of study  \n• \ndefine the topic or key terms  \n• \nstate of the purpose of the essay/writing \n• \nprovide an overview of the coverage and/or structure of the writing  \n \nIntroductions to research articles and dissertations tend to be relatively short but quite complex. \nSome of the more common moves include: \n \n• \nestablishing the context, background and/or importance of the topic \n• \ngiving a brief synopsis of the relevant literature  \n• \nindicating a problem, controversy or a knowledge gap in the field of study  \n• \nestablishing the desirability of the research  \n• \nlisting the research questions or hypotheses  \n• \nproviding a synopsis of the research method(s)  \n• \nexplaining the significance or value of the study  \n• \ndefining certain key terms \n• \nproviding an overview of the dissertation or report structure  \n• \nexplaining reasons for the writer's personal interest in the topic  \n \nExamples of phrases which are commonly employed to realise these functions are listed below. \nNote that there may be a certain amount of overlap between some of the categories under which \nthe phrases are listed. \n \nEstablishing the importance of the topic for the world or society \nX is a fundamental property of …. \nX is  fast becoming a key instrument in …. \nX is a common disorder characterised by …. \nX plays an important role in the maintenance of …. \nXs are the most potent anti-inflammatory agents known. \nX is a major public health problem, and the main cause of …. \nXs are one of the most rapidly declining groups of insects in .... \nIn the new global economy, X has become a central issue for …. \nX is the leading cause of death in western-industrialised countries. \nXs are one of the most widely used groups of antibacterial agents and …. \nX is increasingly recognised as a serious, worldwide public health concern. \nX is an important component in the climate system, and plays a key role in Y. \nIn the history of development economics, X has been thought of as a key factor in …. \n \nEstablishing the importance of the topic for the discipline \nA key aspect of X is …. \nX is a classic problem in …. \nA primary concern of X is …. \nX is at the heart of our understanding of …. \nX is an increasingly important area in applied linguistics. \n8 | P a g e  \n \nInvestigating X is a continuing concern within …. \nCentral to the entire discipline of X is the concept of …. \nX and Y have been an object of research since the 1960s \nX is a major area of interest within the field of …. \nThe issue of X has received considerable critical attention. \nX has been studied by many researchers using …. \nOne of the most significant current discussions in legal and moral philosophy is … \n \nEstablishing the importance of the topic (time frame given) \nOne of the most important events of the 1970s was …. \nTraditionally, Xs have subscribed to the belief that …. \nRecent developments in X have heightened the need for …. \nIn recent years, there has been an increasing interest in …. \nRecent trends in X have led to a proliferation of studies that .... \nRecent developments in the field of X have led to a renewed interest in …. \nRecently, researchers have shown an increased interest in …. \nThe past decade has seen the rapid development of X in many …. \nThe past thirty years have seen increasingly rapid advances in the field of …. \nOver the past century there has been a dramatic increase in …. \nX proved a ...

# %%
# It is reccomend to check the text you extracted mannuly

import re

def clean_text(text):
    # Remove specific unwanted patterns (e.g., page numbers, footers)
    text = re.sub(r'Page \d+ of \d+', '', text)
    text = re.sub(r'[\r\n]+', ' ', text)  # Remove explicit carriage returns and newlines
    text = text.strip()
    return text

cleaned_text = clean_text(text)
cleaned_text
# Out:
# "6 | P a g e                                     Major sections                                                              7 | P a g e     Writing Introductions     There are many ways to introduce an academic essay or short paper. Most academic writers,  however, appear to do one or more of the following in their introductions:    •  establish the context, background and/or importance of the topic  •  indicate an issue, problem, or controversy in the field of study   •  define the topic or key terms   •  state of the purpose of the essay/writing  •  provide an overview of the coverage and/or structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex.  Some of the more common moves include:    •  establishing the context, background and/or importance of the topic  •  giving a brief synopsis of the relevant literature   •  indicating a problem, controversy or a knowledge gap in the field of study   •  establishing the desirability of the research   •  listing the research questions or hypotheses   •  providing a synopsis of the research method(s)   •  explaining the significance or value of the study   •  defining certain key terms  •  providing an overview of the dissertation or report structure   •  explaining reasons for the writer's personal interest in the topic     Examples of phrases which are commonly employed to realise these functions are listed below.  Note that there may be a certain amount of overlap between some of the categories under which  the phrases are listed.    Establishing the importance of the topic for the world or society  X is a fundamental property of ….  X is  fast becoming a key instrument in ….  X is a common disorder characterised by ….  X plays an important role in the maintenance of ….  Xs are the most potent anti-inflammatory agents known.  X is a major public health problem, and the main cause of ….  Xs are one of the most rapidly declining groups of insects in ....  In the new global economy, X has become a central issue for ….  X is the leading cause of death in western-industrialised countries.  Xs are one of the most widely used groups of antibacterial agents and ….  X is increasingly recognised as a serious, worldwide public health concern.  X is an important component in the climate system, and plays a key role in Y.  In the history of development economics, X has been thought of as a key factor in ….    Establishing the importance of the topic for the discipline  A key aspect of X is ….  X is a classic problem in ….  A primary concern of X is ….  X is at the heart of our understanding of ….  X is an increasingly important area in applied linguistics.  8 | P a g e     Investigating X is a continuing concern within ….  Central to the entire discipline of X is the concept of ….  X and Y have been an object of research since the 1960s  X is a major area of interest within the field of ….  The issue of X has received considerable critical attention.  X has been studied by many researchers using ….  One of the most significant current discussions in legal and moral philosophy is …    Establishing the importance of the topic (time frame given)  One of the most important events of the 1970s was ….  Traditionally, Xs have subscribed to the belief that ….  Recent developments in X have heightened the need for ….  In recent years, there has been an increasing interest in ….  Recent trends in X have led to a proliferation of studies that ....  Recent developments in the field of X have led to a renewed interest in ….  Recently, researchers have shown an increased interest in ….  The past decade has seen the rapid development of X in many ….  The past thirty years have seen increasingly rapid advances in the field of ….  Over the past century there has been a dramatic increase in ….  X proved an important literary genre in the early Y community.  The changes experienced by Xs over the past decade remain unprecedented.  Xs are on ...

# %%
### Step 2: Preprocess the data

import spacy
from spacy.matcher import Matcher

# Using English language pre-trained model from spaCy, visit for models in other language https://spacy.io/models
! python -m spacy download en_core_web_sm

# Load the SpaCy model
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 58.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.64.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.0)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from spacy.language import Language

doc = nlp(cleaned_text)

def extract_verb_phrases(doc):
    verb_phrases = []
    for token in doc:
        if token.pos_ == 'VERB':
            # Extract the whole subtree of the verb
            subtree = [tok.lower_ for tok in token.subtree]
            verb_phrase = ' '.join(subtree).replace(' ,', ',')
            verb_phrases.append(verb_phrase)
    return verb_phrases

verb_phrases = extract_verb_phrases(doc)
print("Verb Phrases:", verb_phrases)

def extract_expanded_noun_phrases(doc):
    expanded_noun_phrases = []
    for chunk in doc.noun_chunks:
        # Extend to the left for adjectives
        start = chunk.start
        while start > 0 and doc[start - 1].pos_ in ['ADJ', 'ADV']:
            start -= 1
        # Extend to the right for prepositional phrases
        end = chunk.end
        if end < len(doc) and doc[end].pos_ == 'ADP':
            while end < len(doc) and doc[end].pos_ != 'PUNCT':
                end += 1
        expanded_phrase = doc[start:end].text
        expanded_noun_phrases.append(expanded_phrase)
    return expanded_noun_phrases

expanded_noun_phrases = extract_expanded_noun_phrases(doc)
print("Expanded Noun Phrases:", expanded_noun_phrases)
# Out:
# Verb Phrases: ['6 | p a g e                                      major sections                                                               7 | p a g e      writing introductions      there are many ways to introduce an academic essay or short paper .', 'to introduce an academic essay or short paper', 'most academic writers,   however, appear to do one or more of the following in their introductions :    ', 'to do one or more of the following in their introductions', 'most academic writers,   however, appear to do one or more of the following in their introductions :     •   establish the context, background and/or importance of the topic   •   indicate an issue, problem, or controversy in the field of study    •   define the topic or key terms    •   state of the purpose of the essay / writing   •   provide an overview of the coverage and/or structure of the writing      introductions to research articles and dissertations tend to be relatively short but quite complex .  ', 'indicate an issue, problem, or controversy in the field of study    •   define the topic or key terms    •   state of the purpose of the essay / writing   •   provide an overview of the coverage and/or structure of the writing      introductions to research articles and dissertations tend to be relatively short but quite complex', 'define the topic or key terms   ', 'the essay / writing  ', 'provide an overview of the coverage and/or structure of the writing      introductions to research articles and dissertations', 'to research articles and dissertations', 'tend to be relatively short but quite complex', "some of the more common moves include :     •   establishing the context, background and/or importance of the topic   •   giving a brief synopsis of the relevant literature    •   indicating a problem, controversy or a knowledge gap in the field of study    •   establishing the desirability of the research    •   listing the research questions or hypotheses    •   providing a synopsis of the research method(s )    •   explaining the significance or value of the study    •   defining certain key terms   •   providing an overview of the dissertation or report structure    •   explaining reasons for the writer 's personal interest in the topic      examples of phrases which are commonly employed to realise these functions are listed below .  ", 'establishing the context, background and/or importance of the topic   •  ', "giving a brief synopsis of the relevant literature    •   indicating a problem, controversy or a knowledge gap in the field of study    •   establishing the desirability of the research    •   listing the research questions or hypotheses    •   providing a synopsis of the research method(s )    •   explaining the significance or value of the study    •   defining certain key terms   •   providing an overview of the dissertation or report structure    •   explaining reasons for the writer 's personal interest in the topic      examples of phrases which are commonly employed to realise these functions are listed below", 'indicating a problem', 'establishing the desirability of the research    •  ', 'listing the research questions or hypotheses   ', 'providing a synopsis of the research method(s )    •  ', 'explaining the significance or value of the study   ', 'defining certain key terms  ', 'providing an overview of the dissertation or report structure   ', 'report structure   ', "explaining reasons for the writer 's personal interest in the topic      examples of phrases which are commonly employed to realise these functions are listed below", 'which are commonly employed to realise these functions are listed below', 'to realise these functions are listed below', 'these functions are listed below', 'note that there may be a certain amount of overlap between some of the categories under which   the phrases are listed .    ', 'under which   the phrases are listed', 'establishing the importance of the topic for the world or society   x', ' ...
# Expanded Noun Phrases: ['e                                     Major sections', 'e', 'Introductions', 'many ways', 'an academic essay', 'short paper', 'Most academic writers', 'the following in their introductions', 'their introductions', 'the context', 'background', 'importance of the topic  •  indicate an issue', 'the topic', 'an issue', 'problem', 'controversy in the field of study   •  define the topic or key terms   •  state of the purpose of the essay/writing  •  provide an overview of the coverage and/or structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex', 'the field of study   •  define the topic or key terms   •  state of the purpose of the essay/writing  •  provide an overview of the coverage and/or structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex', 'study', 'the topic', 'key terms', 'state of the purpose of the essay/writing  •  provide an overview of the coverage and/or structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex', 'the purpose of the essay/writing  •  provide an overview of the coverage and/or structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex', 'an overview of the coverage and/or structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex', 'the coverage', 'structure of the writing     Introductions to research articles and dissertations tend to be relatively short but quite complex', 'the writing     Introductions', 'articles', 'dissertations', 'Some of the more common moves include', 'the more common moves', 'the context', 'background', 'importance of the topic  •  giving a brief synopsis of the relevant literature   •  indicating a problem', 'the topic', 'a brief synopsis of the relevant literature   •  indicating a problem', 'the relevant literature', 'a problem', 'the field of study   •  establishing the desirability of the research   •  listing the research questions or hypotheses   •  providing a synopsis of the research method(s', 'study', 'the desirability of the research   •  listing the research questions or hypotheses   •  providing a synopsis of the research method(s', 'the research', 'the research questions', 'hypotheses', 'a synopsis of the research method(s', 'the research method(s', 'the significance', "value of the study   •  defining certain key terms  •  providing an overview of the dissertation or report structure   •  explaining reasons for the writer's personal interest in the topic     Examples of phrases which are commonly employed to realise these functions are listed below", 'the study', 'certain key terms', "an overview of the dissertation or report structure   •  explaining reasons for the writer's personal interest in the topic     Examples of phrases which are commonly employed to realise these functions are listed below", 'the dissertation', 'structure', "reasons for the writer's personal interest in the topic     Examples of phrases which are commonly employed to realise these functions are listed below", "the writer's personal interest in the topic     Examples of phrases which are commonly employed to realise these functions are listed below", 'the topic', 'Examples of phrases which are commonly employed to realise these functions are listed below', 'phrases', 'which', 'these functions', 'a certain amount of overlap between some of the categories under which  the phrases are listed', 'overlap between some of the categories under which  the phrases are listed', 'some of the categories under which  the phrases are listed', 'the categories under which  the phrases are listed', 'which', 'the phrases', 'the importance of the topic for the world or society  X is a fundamental property of', 'the topic for th ...

# %%
import re

# Combine lists and remove duplicates
combined_phrases = set(expanded_noun_phrases + verb_phrases)


# Define a function to apply multiple filters
def is_valid_phrase(phrase):
    # Check for digits
    if any(char.isdigit() for char in phrase):
        return False
    # Check for specific special characters
    if any(char in phrase for char in ['(', ')', '-', '*', '/', '?', '=', '!', '@', '→',':', 'et al',
                                       '#', '$', '%', '^', '&', '<', '>', '[', ']', '  ', '\'',
                                       '{', '}', '|', '\\', '~', '`', '+', '_','•', ',', '/',
                                       '‘','’', '“', '”', '.', '—', '…', '°', '€', '£', '¥']):
        return False

    # remove normal phrases
    words_to_match = ['women', 'man', 'to do', 'grammar','icv','noun','dog','cat','v','c','p','d','P','re']
    if any(re.search(r'\b' + re.escape(word) + r'\b', phrase) for word in words_to_match):
        return False

    # Check for uppercase letters not at the start
    if re.search(r'\s[A-Z]', phrase):
        return False
    return True

# sort
sorted_phrases = sorted({phrase for phrase in combined_phrases if 1 < len(phrase.split(' ')) < 5 and len(phrase) > 2 and is_valid_phrase(phrase)})

# %%
### Step 3: Save the data

# Write the sorted phrases to a Markdown file
with open('../academic_phrasebank.md', 'w') as file:
    for phrase in sorted_phrases:
        cleaned_phrase = re.sub(r'\n*', '', phrase)
        print(cleaned_phrase)
        file.write(cleaned_phrase + '\n')
# Out:
# A better study
# A broader perspective
# A case study approach
# A further definition
# A further study
# A future study
# A good recommendation
# A holistic approach
# A key policy priority
# A minority of participants
# A more comprehensive study
# A pattern
# A positive correlation
# A projection
# A quantitative approach
# A reasonable approach
# A relationship
# A scatter diagram
# A small sample
# A systematic literature review
# A trend
# Academic writers
# Adverbial phrases
# All figures
# All singular countable nouns
# All studies
# All the studies
# Almost every paper
# An arguable weakness
# An issue
# Another important finding
# Another important practical implication
# Another interviewee
# Another noticeable difference
# Another potential problem
# Another question
# Another reason
# Appetitive stimuli
# Article references
# Associative learning
# Background information
# Blood samples
# Both words
# Case studies
# Common problems
# Comparison within one sentence
# Complex sentences
# Compound sentences
# Considerably more work
# Contracted forms
# Countable words
# Cycling alters
# Data management
# Describing trends
# Descriptive data
# Devices for avoiding over
# Different authors
# Discussion sections
# Drinking alcohol
# Early involvement
# Extreme loneliness
# Five broad themes
# Five individuals
# Full stop
# Further analysis
# Further data collection
# Further experimental investigations
# Further investigation
# Further research
# Further statistical tests
# Further studies
# Further work
# Future research
# Gas production
# General meanings
# German academics
# Independent tests
# Initial observations
# Injection solutions
# Introducing lists
# Invasive plants
# Japanese history
# Large randomised controlled trials
# Many analysts
# Many children
# Many diseases
# Many historians
# Many other medications
# Many paragraphs
# Many scholars
# Many sentences
# Many writers
# More recent attention
# More research
# Most academic writers
# Multiple regression analysis
# My thesis
# No difference
# No previous study
# No significant differences
# Numerous studies
# Oil production
# One individual
# One major theoretical issue
# One observer
# One question
# One unanticipated finding
# Only children
# Other authors
# Other researchers
# Other studies
# Otherwise no article
# Ozone levels
# Physical activity
# Plural countable nouns
# Possible cause
# Post hoc analysis
# Prepositional phrases
# Previous research
# Previous studies
# Prior studies
# Projecting trends
# Published studies
# Qualitative methods
# Quotation marks
# Radiographic techniques
# Recent cases
# Recent evidence
# Recent research
# Recently investigators
# Reference to previous research
# Regression analysis
# Research questions
# Roman slaves
# Several attempts
# Several questions
# Several studies
# Significance levels
# Simple sentences
# Simple statistical analysis
# Small sample sizes
# So far this method
# So it
# Some analysts
# Some authors
# Some interviewees
# Some participants
# Some sentences
# Some students
# Some studies
# Some writers
# Specific classifications
# Statistical significance
# Such expositions
# Summarising research findings
# Supporters of the
# Synthesising sources
# Systems theory
# The analysis
# The annual birth rate
# The authors
# The books
# The case
# The changes
# The chapter
# The controlling idea
# The corpus callosum
# The current findings
# The current investigation
# The current research
# The current study
# The data
# The essay
# The evidence
# The example
# The examples
# The existing accounts
# The experimental data
# The experiments
# The final chapter
# The final comment
# The findings
# The first group
# The first part
# The first section
# The first serious discussions
# The following
# The following conclusions
# The following section
# The fourth section
# The graph
# The human papilloma virus
# The hypothesis
# The initial sample
# The issue
# The latter point
# The main error
# The main questions
# The medium
# The methodological approach
# The methods
# The more surprising correlation
# The most common difference
# The most important limitation
# The most interesting finding
# The most obvious finding
# The most striking result
# The new material
# The next chapter
# The participants
# The past decade
# The past thirty years
# The pie chart
# The pilot interviews
# The present findings
# The present perfect tense
# The present results
# The present study
# The prices of resources
# The process
# The project
# The proposed model
# The reader
# The reason
# The respondents
# The response rate
# The resulting solution
# The results
# The sample
# The sample size
# The second major finding
# The second sentence
# The soil
# The solution
# The structure
# The students
# The studies
# The study
# The subject
# The subjects
# The table
# The term
# The term disease
# The test
# The themes
# The thesis
# The third chapter
# The tubes
# The two parts
# The verb
# The verbs
# The vials
# The warm air
# These analytical procedures
# These claims
# These comments
# These data
# These differences
# These experiments
# These factors
# These findings
# These frequent storms
# These ratings
# These results
# These simple sentences
# These sources
# These studies
# These views
# This account
# This case
# This case study
# This chapter
# This compound
# This concept
# This definition
# This difference
# This discrepancy
# This dissertation
# This distinction
# This essay
# This experiment
# This figure
# This finding
# This inconsistency
# This information
# This interpretation
# This introductory section
# This limitation
# This paper
# This project
# This rather contradictory result
# This research
# This result
# This section
# This structure
# This study
# This table
# This test
# This theme
# This thesis
# This topic
# This view
# This work
# Time phrases
# Together these results
# Together these studies
# Twenty cohort study analyses
# Two discrete reasons
# Uncountable nouns
# Unexpected outcome
# Various other sentence elements
# Verb structures
# X after reading
# X amongst interviewees
# X as
# X bone
# X by demonstrating
# X cells
# X in
# X in many
# X in much detail
# X into account
# X on
# X procedure
# X software
# X studies
# X than
# Xs after reading
# Y bone
# Y in murine
# Y in several cases
# Young children
# Young people
# Your spell checker
# a basic belief
# a bell
# a biological event
# a brief overview of
# a brief summary
# a classic problem in
# a colleague
# a combination of
# a common disorder
# a complex problem
# a concept
# a conceptual theoretical framework
# a conical flask
# a continuing concern within
# a controlling idea
# a convenience sample
# a correlation
# a crime
# a critical role for
# a cross sectional design
# a debate
# a definite need for
# a definition
# a delayed onset of
# a determiner
# a diet
# a digital audio recorder
# a direct quotation
# a disease
# a distinction between
# a dramatic increase in
# a driver
# a factor
# a few simple rules
# a film
# a final comment
# a following section
# a full stop
# a fundamental property of
# a furnace
# a g
# a g e
# a good illustration of
# a grammatically complex list
# a high level
# a history of
# a key factor in
# a lack of iodine
# a large longitudinal study
# a link between
# a list
# a longitudinal analysis of
# a lower speed limit
# a major factor
# a means of
# a medical advisor
# a minority
# a mixed methodology
# a need
# a new idea
# a new topic
# a new understanding of
# a new word
# a number
# a number of important
# a number of limitations
# a number of respects
# a number of writers
# a paper
# a paragraph
# a particular method
# a particular study
# a phrase
# a pool of
# a poorly defined term
# a positive impact on
# a possessive determiner
# a possibility
# a powerful effect
# a problem
# a process of analysis
# a proposition
# a public place
# a qualification
# a question
# a questionnaire
# a quoted text
# a reaction
# a recorded conversation
# a reduced ability
# a research article
# a result
# a rigorous study
# a search strategy
# a section
# a sentence
# a serious effect on
# a short paper
# a significant difference
# a significant difference between
# a significant increase
# a small chance
# a small modifying word
# a small sample size
# a soil sample from
# a specific date
# a specific group
# a state
# a statement
# a strong possibility
# a study
# a survey
# a system
# a systematic approach
# a systematic way
# a table
# a tendency
# a term
# a text
# a title
# a topic
# a variety of reasons
# a variety of ways
# a verb
# a very complex area
# a weak link
# a whole
# a widely held view
# a word
# a worldwide epidemic
# a writer
# above we
# absolute certainty
# academic activity
# academic communication
# academic style
# academic texts
# academic work
# academic work students
# academic writers
# academic writing
# academic writing concerns verbs
# account of
# accuracy on this matter
# action for
# additional evidence
# additional information
# additional relevant publications
# addressed in this paper
# adopted for this study
# aiming to provide
# alcohol than adults
# all patients
# all sentences
# all the groups of
# all variables
# always the case
# an abbreviation
# an academic essay
# an academic writer
# an account of
# an action
# an actual sensation
# an adjective
# an adverb
# an aid
# an apostrophe
# an argument
# an article
# an attempt
# an effect
# an effect on
# an effective way of
# an elementary particle
# an essay
# an examination of
# an example of
# an exciting opportunity
# an explanation
# an exploratory investigation
# an idea
# an important factor in
# an important opportunity
# an increase in
# an institution
# an interviewee
# an intriguing one
# an issue
# an overview of
# an understanding of
# anonymised questionnaires
# another major study
# another meaning
# another person
# another weakness
# answering questions
# antibacterial agents
# any evidence
# any evidence for
# any research
# any significant differences between
# any significant increase in
# any stimulus
# any test
# applied fields
# applied linguistics
# are avoided
# are replaced with statements
# arguing that
# arrival at the clinic
# as follows
# as obesity does
# as they are presented
# as x is concerned
# as you read
# associated with
# associated with obesity
# at least three limitations
# attending emergency departments
# attractive features
# author as subject
# average life expectancy
# band intensity pattern
# based on
# before x is introduced
# behaviour of matter
# behaviour problems in
# best known
# better strategies for
# biosynthetic incorporation
# both forms
# break down tissues
# breast cancer
# bringing about
# broad biological terms
# cautious interpretation
# cautious interpretation of findings
# certain bacterial infections
# certain cases
# certain disciplines
# certain drawbacks
# certain key terms
# certain limitations
# certain precision manual tasks
# certain qualities
# changing over time
# cholesterol levels
# choosing this topic
# church authorities
# classical and operant conditioning
# classical origin
# climate change
# commencing the study
# committing a crime
# common examples
# commonly confused
# commonly confused words
# commonly referred to
# comparative forms
# compared with placebo
# comparing the two results
# comparing x with y
# competitive sport
# complete sentences
# complex sentence
# concluded that
# conducted on
# connecting the two hemispheres
# consequences of social problems
# considerable critical attention
# considerable criticism
# considerable debate
# constructive suggestions
# constructive thinking
# contracted forms
# contradictory findings about
# contrast to earlier findings
# contrast to oral communities
# cooling properties
# countable nouns
# criticism from governments
# critique of the findings
# custom software
# data being gathered via
# death in western
# defined as xyz
# deionized water
# derived from the verbs
# describing the process
# detailed analysis of
# detailed information
# developed in
# development economics
# differences between things
# differences between two things
# differences in
# different conclusions
# different disciplines
# different quantities of
# discussion sections
# discussions of
# distinct functions in
# doing this
# drinking alcohol
# earlier findings
# earlier studies
# early death
# economic growth
# effect relationships
# elsewhere it
# email advertisements
# emergency departments
# emerging from this finding
# empirical research
# empirical studies
# entitled expressing caution
# establish what
# ethical clearance
# evaluation of
# evaluative adjectives
# everyday words
# exactly what
# example in discussions of
# exempli gratia
# experimenter bias
# explaining keywords
# explanations for findings
# expressed in general terms
# extensive research
# external sources
# facilitating and promoting
# far the greatest demand
# far too little attention
# few empirical investigations into
# few writers
# fewer errors than men
# fewer injuries to pedestrians
# finding no increase in
# fine distinctions between
# five movements
# focus group discussions
# focus groups
# followed by supporting information
# following this
# formal academic writing
# four abilities
# four different ways
# four kinds
# four main sections
# four main sources
# four overlapping senses
# four parts
# four themed chapters
# further examples
# further investigation
# further progress in determining
# further research
# further research work
# future change
# future directions
# future investigations
# future practice
# future research
# future studies
# future work
# general hypotheses
# general implications
# general propositions
# general terms
# generally accepted
# given a title
# given below
# given here
# giving examples
# global warming
# grammatical words
# great works of science
# greater detail
# habits of constructive thinking
# has argued that
# have revealed that
# healthy students from
# heavy water
# hedging devices
# height measurement
# her analysis of
# her classic critique of
# her data
# her major study
# her seminal article
# high blood pressure
# higher compression
# his book
# his findings
# his seminal study
# his study
# homogeneity of their
# however relevant it
# human health
# ideas of writers
# important changes
# important implications for developing
# important limitations
# important ways
# important words
# in vitro studies
# in which they described
# included in his study
# including this introductory chapter
# increasing concern
# increasing concern over
# indicates its content
# indicating a problem
# indicating addition
# individuals within the same
# infant mortality
# inflowing surface water
# informal systems
# information on
# initial screening
# innovative marketing strategies in
# insects in
# intense debate within
# interesting findings
# international students
# interpretation of data
# investigating x
# involved in x
# involving x
# iron ore
# irrational belief
# is given below
# it as
# it has
# its acceptance
# its advantages
# its broadest sense
# its claims
# its content
# its effects
# its exploratory nature
# its long clinical success
# its long duration
# its relevance to
# its safety
# its therapeutic implications
# judgement on this
# just over half
# key terms
# key words
# lack of exercise
# laid out
# language learning
# language teaching
# learn more about both
# learning ability
# led to
# legal and moral philosophy
# light of recent
# limited comparisons of
# listed in a text
# literate cultures
# literate societies
# literature on
# little agreement on what
# little discussion about
# little evidence
# little evidence for this
# little progress
# little quantitative analysis of
# living organisms
# longer piece of writing
# longitudinal studies
# looks at how
# losing some benefits
# low pressure
# main focus
# mainstream schools
# maintaining fitness
# making scales homogenous
# many arguing that
# many cases
# many cities
# many disagreements
# many earlier studies
# many fields
# many good reasons
# many instances
# many investigational studies
# many other prominent scholars
# many others
# many researchers
# many sentences
# many situations
# many species
# many studies
# many ways
# many words
# many years
# many years concerns
# mean life expectancy
# medicine as the conscious
# mental disability
# millionaire households
# minority groups
# misinterpretation may result
# model specification
# more definitive evidence
# more than one word
# most cervical cancer
# most rapidly declining
# most recent studies
# most widely used
# much detail
# much more information
# much published
# much uncertainty
# my thesis
# my time
# need of further investigation
# negative result
# new facts
# new point
# new points
# no attempt
# no consensus about
# no controlled studies
# no data
# no differences
# no equivalent
# no evidence
# no explanation of how
# no general agreement about
# no increase in
# no reliable evidence
# no research
# no significant differences between
# no single study
# no studies
# normally used for this
# not much research
# not to be used
# observed in earlier studies
# obtained from them
# often an article
# often conflicting
# often observed in
# older people
# one interviewee
# one sentence
# one topic to another
# one way
# one word
# only consist
# only two studies
# oral communities
# oral cultures
# oral societies
# other cases
# other information
# other people
# other phrases
# other possible explanations
# other reasons for
# other research
# other studies
# other variables
# other words
# other writers
# our definition of
# our earlier observations
# our knowledge of
# our understanding of
# outside marriage
# over a century
# paragraph structure
# parameter estimation
# part from stress
# particular attention to
# particularly the thoracic spine
# patients with
# people at risk of
# people in oral cultures
# perceptual speed
# personal interest
# personal pronouns
# physical attributes
# place in a
# placed in
# poor diet
# poor health
# poorly defined
# positive result
# possible future studies
# postgraduate level
# poststructuralist theory
# practical constraints
# presented in this section
# preventative medicine
# previous findings
# previous research
# previous studies
# previous work
# previously mentioned
# previously used
# previously used methods
# problems in use
# proceeding to examine x
# produced so far
# prolonged use of
# protein concentration
# protein sample
# psychological works
# publications in the past
# published studies
# qualitative analysis of
# qualitative case studies
# qualitative data
# qualitative modes of enquiry
# qualitative results
# quantitative and qualitative approaches
# quantitative measures
# quantitative research designs
# quantitative studies
# questionnaire required
# randomly selected
# rank importance
# reading difficult
# real examples
# real terms
# recent reports
# recent research
# recent years
# recommendations for future work
# refer to discussing findings
# reference to external sources
# references to previous research
# referring to sources
# regarding the present study
# regular exercise
# related to
# related to x
# relating to
# reliable predictors of
# reported here
# reported that
# reproduce the results
# research articles
# research by exploring
# research contribution
# research in
# research papers
# research reports
# researchers in many fields
# respect to
# response to the question
# restrictions on academics
# results section
# returned the questionnaire
# reviewing the literature
# risk of
# scientific writing
# selecting the subjects
# selection on
# sense by itself
# sentence structure
# sentence subject
# sequence words
# serious drawbacks
# several aspects of
# several cases
# several divisions
# several important areas
# several key features
# several major drawbacks
# several noteworthy contributions to
# several practical applications
# several reasons
# several sources
# several sources for error
# several studies
# several ways
# short paper
# showing its relevance to
# shown in these
# signalling this
# significant clusters of
# significant differences
# significant new ideas
# single cells into different
# single investigations
# six chapters
# six decimal places
# six main research questions
# six months
# six sections
# social problems
# social scientists
# societies with
# solutions to problems
# some agreement
# some cases
# some catastrophic decisions
# some disciplines
# some doubt
# some evidence
# some exceptions
# some other differences
# some other stimulus
# some previewing statements
# some published studies
# some research
# some way
# specific studies
# spectra typing
# speculating on future directions
# stored overnight at
# strength of knowledge
# strong recommendations to
# study findings
# studying x
# subsequent sentences
# such an approach
# such connections
# such explanations
# suggest that
# suggesting implications
# suggesting solutions to problems
# suggests that
# summary statement
# supported by subsequent sentences
# supporting information
# taken in this study
# taken together
# talking about this issue
# targetted interventions
# ten minutes
# terms of
# tests of perceptual speed
# tests of target
# text based
# text based studies
# text to another
# than x was observed
# that acts on
# that could be asked
# that demonstrated
# that exist among
# that follow
# that follows
# that have reported
# that investigate how
# that is undertaken
# that suggests
# that surveyed
# that there is less
# that these students lack
# that to explore
# that will be tested
# that you read
# that you use
# the aim
# the analysis
# the appliance
# the applied human sciences
# the area
# the articles
# the assumption
# the attitudes
# the author
# the authors
# the background readings
# the basis of
# the belief
# the best method
# the brain
# the case
# the case of
# the case study
# the causative factor of
# the causes
# the causes of illiteracy
# the cells
# the challenges
# the changing nature of
# the characters
# the chart
# the claim
# the claims
# the climate system
# the clinic
# the composition
# the computer
# the computer screen
# the concentrate
# the conceptual premise
# the conclusion
# the conclusions
# the constructions
# the context
# the context of
# the control group
# the correlational analysis
# the course of
# the coverage
# the current findings
# the current literature
# the current study
# the current topic
# the current work
# the data
# the data analysis
# the data comparison
# the dataset
# the debate
# the decline of
# the definite article
# the definition
# the degree
# the dependent part
# the developing world
# the development of
# the differences between
# the dissertation
# the distributions
# the doses
# the effect of
# the effects of
# the end
# the end of
# the entire thesis
# the epistemological strength
# the equipment
# the events
# the evidence for
# the example
# the examples
# the existence of something
# the experiment
# the experiment failed
# the experimental evidence on
# the experimental method
# the explicit language
# the exposures
# the extent
# the fact
# the failure
# the field
# the field of
# the field of linguistics
# the fifth century
# the findings
# the first people
# the first study
# the first time
# the focus
# the following areas
# the following industrial centres
# the following questions
# the following research questions
# the following section
# the following way
# the food
# the former situation
# the forthcoming sections
# the four years from
# the future
# the genes
# the graph
# the greenhouse effect
# the grounds
# the growing period from
# the heading
# the historical research
# the horizontal axis
# the humanities
# the hypothesis
# the idea
# the idea of
# the ideas
# the imagination as
# the impact of
# the implications of these
# the importance of
# the increase in
# the independent part
# the individual author
# the information
# the instrument
# the intellectual landscape
# the intended audience
# the interests of objectivity
# the interview data
# the interviews
# the introduction
# the investigation
# the investigation of
# the issues
# the key ideas
# the lack of adequate
# the language
# the laptop
# the largest study
# the last item
# the left brain
# the literature
# the literature of
# the literature review
# the long term
# the low response rate
# the lowest value of
# the main cause of
# the main findings
# the main meaning
# the main part
# the main text
# the major causes of
# the majority
# the maximum temperature
# the meaning
# the measurement causes
# the mechanism by which
# the method
# the methodology
# the methods
# the more common moves
# the more detailed information
# the more extreme weather
# the more significant findings
# the most intense reactions
# the movement
# the multivariate method
# the mysteries
# the need
# the need for
# the new approach
# the new global economy
# the new policies
# the next chapter
# the next section
# the nineteenth century
# the nouns
# the one sentence
# the operations of
# the order
# the other hand
# the other tables
# the other thing
# the pages
# the paper
# the paper proceeds
# the participants
# the passive form
# the past
# the past century
# the past decade
# the past few decades
# the past forms
# the past two decades
# the patients
# the paucity of
# the period
# the personal pronoun
# the phrases
# the point
# the policy
# the population
# the population rise
# the positions
# the possibility
# the potential
# the poverty cycle
# the present
# the present report
# the present results
# the present study
# the present tense
# the previous chapter
# the previous discussion
# the previous page
# the previous research
# the previous sentence
# the previous studies
# the primary sources
# the principal issues
# the problem
# the problem of
# the procedure
# the procedures
# the process
# the project
# the pronoun
# the provision of
# the purpose of analysis
# the question
# the question of
# the questionnaire
# the questionnaire required respondents
# the questionnaires
# the ratios of
# the raw data
# the reader
# the reasons
# the reasons for
# the relation between
# the relationship
# the relationship between
# the relevance
# the relevant literature
# the reliability of measures
# the report
# the research
# the research area
# the research design
# the research questions
# the researcher
# the researchers
# the respondents
# the results
# the results section
# the review
# the right brain
# the rise of
# the role of
# the same meaning as
# the same measurement
# the same method
# the same term
# the same vein
# the same way
# the samples
# the science
# the scientific community
# the scores
# the sea
# the sea floor
# the second world war
# the section
# the selection criteria
# the selective introduction of
# the sentence
# the sentences
# the significance
# the significance of
# the significant data
# the simple past tense
# the situation
# the soil
# the solutions
# the source
# the source text
# the sources
# the specific parts
# the spellchecker
# the spine
# the statistical analysis
# the strategy
# the structure
# the studies
# the study
# the study population
# the subject
# the subjects
# the subsequent chapter
# the subsurface
# the survey
# the survey period
# the table
# the ten stimuli
# the term
# the term education
# the terminology in
# the texts
# the thematic linking
# the themes
# the thesis
# the thinking
# the three key themes
# the topic
# the topic sentence
# the trained interviewer
# the transport system
# the trend in
# the trial
# the two conditions
# the two groups
# the two hemispheres
# the two methods
# the two results
# the two trials
# the understanding of
# the use of
# the use of pesticides
# the usefulness of
# the various tenses
# the varying
# the verb
# the verbs
# the view
# the war
# the water
# the ways in which
# the welfare system
# the whole
# the widely held view
# the word
# the words
# the words in bold
# the work
# the world
# the writer
# the writing
# their ability
# their arguments
# their conclusion
# their discipline
# their general claims
# their growth
# their introductions
# their methods
# their performance on
# their readers
# their research
# their results
# their students
# their text
# their tutors
# their work
# them as
# themselves from the writing
# then the definite article
# then these
# there are some exceptions
# these adverse events
# these are explained below
# these cases
# these conditions
# these convey
# these criticisms
# these cycles
# these differences
# these disorders
# these earlier findings
# these factors
# these findings
# these four economies
# these frequent storms
# these functions
# these general patterns
# these limitations
# these measures
# these parts
# these questions
# these rapid changes
# these research gaps
# these responses
# these results
# these simple rules
# these students
# these studies
# these subsets as
# these terms
# these theories
# these two possibilities
# these variables
# these variables into account
# these variations
# these words
# they make
# this analysis
# this approach
# this area
# this argument
# this article
# this brain area
# this case
# this chapter
# this collection
# this condition
# this correlation
# this data
# this difference
# this dissertation
# this document
# this effect
# this essay
# this explanation
# this field
# this finding
# this instrument
# this introductory chapter
# this investigation
# this issue
# this item
# this kind
# this kind of language
# this kind of transformation
# this matter
# this method
# this one
# this paper
# this paper addresses
# this phenomenon
# this pilot study
# this point
# this project
# this question
# this reason
# this relationship
# this report
# this research
# this research project
# this research support
# this result
# this section
# this simple pattern
# this study
# this study mirror
# this study show
# this system
# this table
# this thesis
# this to you
# this topic
# this way
# this weight
# this work
# those of
# those who
# three elements
# three factors
# three headings
# three reasons
# three separable basic functions
# time frame
# to address how
# to allow
# to analyse these variables
# to ask
# to assess
# to assess the various
# to assess x
# to be acknowledged
# to be asked
# to be considered
# to be developed
# to be elucidated
# to be increased
# to be influencing
# to be interpreted cautiously
# to be linked to
# to be made
# to be moved forward
# to be stated
# to be undertaken
# to be used
# to become adults
# to carry out
# to cause
# to come before
# to consider the
# to control for bias
# to cross
# to date none has
# to defend the view
# to define nursing
# to define precisely
# to demonstrate that
# to describe
# to describe this phenomenon
# to describe x
# to design
# to determine
# to discuss
# to enhance x
# to establish this
# to estimate
# to examine more closely
# to examine x
# to explain
# to explain this result
# to explore the subsurface
# to follow
# to fully define what
# to give information on
# to give presentations
# to have
# to have received
# to identify
# to identify students who
# to implement the policy
# to indicate
# to indicate additional information
# to indicate possession
# to indicate that
# to introduce an explanation
# to investigate
# to investigate why
# to mean
# to measure
# to measure x
# to note that
# to obtain
# to obtain many others
# to occur in
# to overlook the fact
# to praise someone
# to provide
# to question two
# to read
# to reduce experimenter bias
# to refer to
# to refer to all
# to refer to particular
# to remember
# to remove
# to restrict
# to show
# to show that
# to specify whether
# to stand
# to study
# to study a topic
# to suggest that
# to suggest that the
# to support the assumption
# to tackle this issue
# to use the term
# to work in adulthood
# to write essays
# together the main areas
# too much nominalisation
# touch reading
# transition statements
# transport growth
# twenty to thirty years
# two basic approaches
# two broad types
# two functions
# two groups
# two independent parts
# two main parts
# two parts
# two sentences
# two things
# two types
# two types of activity
# two types of information
# uncountable nouns
# undernourished children
# understanding differences between things
# undertaken by
# undertaken by teams
# undertaken here
# undertaking the investigation
# unfamiliar or difficult concepts
# unless governments adopt x
# unprotected nerve cells
# urban and rural areas
# us to understand
# us to understand this
# used for this study
# used for this x
# used in the writing
# used in this investigation
# used to determine
# using the multivariate method
# using the personal pronoun
# using x software and
# various ages
# various methods
# various time points during
# various ways
# various well known limitations
# verb tenses
# very few studies
# very much attention
# vitro resistance to
# way of illustration
# ways of
# well known
# were asked to
# what follows
# what ideas
# what is now needed
# what respects
# what work
# when implementation ends and
# when reporting qualitative results
# when they are contextualised
# when they grow up
# when we classify things
# when you are writing
# where they are going
# which found
# which found that
# which showed
# which showed that
# which shows
# while others considered that
# who answered this question
# who argue that
# who argues that
# who completed the questionnaire
# who describes
# who found that
# who suggested that
# who were interviewed
# who writes that
# whose function
# why xs have declined
# widely held
# words like organisation
# working with x
# world production
# writing definitions
# written academic style
# written in
# x refers that to
# yet it
# you are researching
